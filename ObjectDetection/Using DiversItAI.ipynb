# %% [markdown]
# ## Using DiversItAI

# %% [markdown]
# ### 1. Import Libraries

# %%
import imutils
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Import both functions from DiversItAI Library

# %%
from DiversItAI import multiple_contours , single_contours

# %% [markdown]
# ### 3. Set Paths for the images

# %%
path="test_images/flower.jpg"
path1="test_images/dogs.jpg"

# %% [markdown]
# #### Visualize both the images

# %%
image1=cv2.imread(path)
image1=cv2.cvtColor(image1, cv2.COLOR_BGR2RGB)

plt.imshow(image1)

# %%
image2=cv2.imread(path1)
image2=cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
plt.imshow(image2)

# %% [markdown]
# ### 4. For multiple Detection

# %% [markdown]
# Pass the Path to `multiple_contours` function imported.

# %% [markdown]
# For first image

# %%
a= multiple_contours(path)

# %%
plt.imshow(a)

# %% [markdown]
# For second image

# %%
a= multiple_contours(path1)

# %%
plt.imshow(a)

# %% [markdown]
# ### 5. For Single Detection
#
# Pass the Path to `single_contours` function imported.

# %% [markdown]
# For first

# %%
b= single_contours(path)

# %%
plt.imshow(b)

# %% [markdown]
# For second

# %%
b= single_contours(path1)

# %%
plt.imshow(b)
